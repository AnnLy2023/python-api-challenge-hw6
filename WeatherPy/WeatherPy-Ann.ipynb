# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 591

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL

url = "https://api.openweathermap.org/data/2.5/weather?"
units = "metric"
base_url = f"{url}appid={weather_api_key}&units={units}&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{base_url}{city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | colonia
# Processing Record 2 of Set 1 | opuwo
# Processing Record 3 of Set 1 | port elizabeth
# Processing Record 4 of Set 1 | grytviken
# Processing Record 5 of Set 1 | naze
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | talnakh
# Processing Record 8 of Set 1 | fort st. john
# Processing Record 9 of Set 1 | utrik
# Processing Record 10 of Set 1 | wailua homesteads
# Processing Record 11 of Set 1 | longyearbyen
# Processing Record 12 of Set 1 | muroto-misakicho
# Processing Record 13 of Set 1 | magdagachi
# Processing Record 14 of Set 1 | tambacounda
# Processing Record 15 of Set 1 | port-aux-francais
# Processing Record 16 of Set 1 | buala
# Processing Record 17 of Set 1 | adamstown
# Processing Record 18 of Set 1 | sawakin
# Processing Record 19 of Set 1 | isafjordur
# Processing Record 20 of Set 1 | lebu
# Processing Record 21 of Set 1 | kodiak
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | horta
# Processing Record 25 of Set 1 | pemangkat
# Processing Record 26 of Set 1 | chonchi
# Processing Record 27 of Set 1 | maun
# Processing Record 28 of Set 1 | beolgyo
# Processing Record 29 of Set 1 | ust'-kulom
# Processing Record 30 of Set 1 | sitka
# Processing Record 31 of Set 1 | chui
# Processing Record 32 of Set 1 | puerto natales
# Processing Record 33 of Set 1 | bengkulu
# Processing Record 34 of Set 1 | bilibino
# Processing Record 35 of Set 1 | broome
# Processing Record 36 of Set 1 | salekhard
# Processing Record 37 of Set 1 | kuta
# Processing Record 38 of Set 1 | yellowknife
# Processing Record 39 of Set 1 | edinburgh of the seven seas
# Processing Record 40 of Set 1 | narasannapeta
# Processing Record 41 of Set 1 | port saint john's
# Processing Record 42 of Set 1 | west island
# Processing Record 43 of Set 1 | espargos
# City not found. Skipping...
# Processing Record 44 of Set 1 | garissa
# Processing Record 45 of Set 1 | emerald
# Processing Record 46 of Set 1 | kapuskasing
# Processing Record 47 of Set 1 | olgii
# City not found. Skipping...
# Processing Record 48 of Set 1 | al abyar
# Processing Record 49 of Set 1 | vorkuta
# Processing Record 50 of Set 1 | papatowai
# Processing Record 0 of Set 2 | margaret river
# Processing Record 1 of Set 2 | gadzhiyevo
# Processing Record 2 of Set 2 | constantia
# Processing Record 3 of Set 2 | bethel
# Processing Record 4 of Set 2 | ayame
# Processing Record 5 of Set 2 | port mathurin
# Processing Record 6 of Set 2 | gaozhou
# Processing Record 7 of Set 2 | nuku'alofa
# Processing Record 8 of Set 2 | iqaluit
# Processing Record 9 of Set 2 | puerto santa
# Processing Record 10 of Set 2 | priargunsk
# Processing Record 11 of Set 2 | hermanus
# Processing Record 12 of Set 2 | mukah
# City not found. Skipping...
# Processing Record 13 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 14 of Set 2 | qaqortoq
# Processing Record 15 of Set 2 | nova xavantina
# Processing Record 16 of Set 2 | waitangi
# Processing Record 17 of Set 2 | banda aceh
# Processing Record 18 of Set 2 | las tablas
# Processing Record 19 of Set 2 | jamestown
# Processing Record 20 of Set 2 | sinjar
# Processing Record 21 of Set 2 | uturoa
# Processing Record 22 of Set 2 | anadyr
# Processing Record 23 of Set 2 | enewetak
# Processing Record 24 of Set 2 | la paz
# Processing Record 25 of Set 2 | kyshtovka
# Processing Record 26 of Set 2 | chibougamau
# Processing Record 27 of Set 2 | dire
# Processing Record 28 of Set 2 | ola
# Processing Record 29 of Set 2 | lospalos
# Processing Record 30 of Set 2 | fort bragg
# Processing Record 31 of Set 2 | udachny
# Processing Record 32 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 33 of Set 2 | stornoway
# Processing Record 34 of Set 2 | santa eularia des riu
# Processing Record 35 of Set 2 | makurazaki
# Processing Record 36 of Set 2 | champerico
# Processing Record 37 of Set 2 | nongstoin
# Processing Record 38 of Set 2 | east london
# Processing Record 39 of Set 2 | pont rouge
# Processing Record 40 of Set 2 | newman
# Processing Record 41 of Set 2 | invercargill
# Processing Record 42 of Set 2 | bredasdorp
# Processing Record 43 of Set 2 | vernon
# Processing Record 44 of Set 2 | labrador city
# Processing Record 45 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 46 of Set 2 | porto novo
# Processing Record 47 of Set 2 | saipan
# Processing Record 48 of Set 2 | olonkinbyen
# Processing Record 49 of Set 2 | tibati
# Processing Record 0 of Set 3 | whiteville
# Processing Record 1 of Set 3 | manaure
# Processing Record 2 of Set 3 | salaqi
# Processing Record 3 of Set 3 | shalkar
# Processing Record 4 of Set 3 | arraial do cabo
# Processing Record 5 of Set 3 | mannargudi
# Processing Record 6 of Set 3 | nago
# Processing Record 7 of Set 3 | stanley
# Processing Record 8 of Set 3 | colac
# Processing Record 9 of Set 3 | vorgashor
# Processing Record 10 of Set 3 | fale old settlement
# Processing Record 11 of Set 3 | nanpara
# Processing Record 12 of Set 3 | riosucio
# Processing Record 13 of Set 3 | college
# Processing Record 14 of Set 3 | hirara
# Processing Record 15 of Set 3 | ust-nera
# Processing Record 16 of Set 3 | torghay
# Processing Record 17 of Set 3 | suva
# Processing Record 18 of Set 3 | weno
# Processing Record 19 of Set 3 | aripuana
# Processing Record 20 of Set 3 | dudinka
# Processing Record 21 of Set 3 | ilulissat
# Processing Record 22 of Set 3 | remire-montjoly
# Processing Record 23 of Set 3 | polyarnyy
# Processing Record 24 of Set 3 | chuguyevka
# Processing Record 25 of Set 3 | vadso
# Processing Record 26 of Set 3 | ngerengere
# Processing Record 27 of Set 3 | sumbe
# Processing Record 28 of Set 3 | albany
# Processing Record 29 of Set 3 | arroyito
# Processing Record 30 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 31 of Set 3 | nar'yan-mar
# Processing Record 32 of Set 3 | mareeba
# Processing Record 33 of Set 3 | regeneracao
# Processing Record 34 of Set 3 | wanganui
# Processing Record 35 of Set 3 | caleta de carquin
# Processing Record 36 of Set 3 | las palmas
# Processing Record 37 of Set 3 | carnarvon
# Processing Record 38 of Set 3 | jieshi
# Processing Record 39 of Set 3 | tarawa
# Processing Record 40 of Set 3 | afaahiti
# Processing Record 41 of Set 3 | fizuli
# Processing Record 42 of Set 3 | tiksi
# Processing Record 43 of Set 3 | berezovyy
# Processing Record 44 of Set 3 | tranovaho
# City not found. Skipping...
# Processing Record 45 of Set 3 | flying fish cove
# Processing Record 46 of Set 3 | vila franca do campo
# Processing Record 47 of Set 3 | trincomalee
# Processing Record 48 of Set 3 | sola
# Processing Record 49 of Set 3 | gorontalo
# Processing Record 0 of Set 4 | slonim
# Processing Record 1 of Set 4 | happy valley-goose bay
# Processing Record 2 of Set 4 | atafu village
# Processing Record 3 of Set 4 | cargados carajos
# City not found. Skipping...
# Processing Record 4 of Set 4 | halifax
# Processing Record 5 of Set 4 | mount isa
# Processing Record 6 of Set 4 | katsuura
# Processing Record 7 of Set 4 | nova sintra
# Processing Record 8 of Set 4 | khorinsk
# Processing Record 9 of Set 4 | preveza
# Processing Record 10 of Set 4 | kayangel
# Processing Record 11 of Set 4 | bejaia
# Processing Record 12 of Set 4 | hasaki
# Processing Record 13 of Set 4 | blackmans bay
# Processing Record 14 of Set 4 | gidam
# Processing Record 15 of Set 4 | barcelos
# Processing Record 16 of Set 4 | boa vista
# Processing Record 17 of Set 4 | lihue
# Processing Record 18 of Set 4 | manismata
# Processing Record 19 of Set 4 | kapa'a
# Processing Record 20 of Set 4 | san patricio
# Processing Record 21 of Set 4 | arno
# Processing Record 22 of Set 4 | sungai penuh
# Processing Record 23 of Set 4 | badger
# Processing Record 24 of Set 4 | port alfred
# Processing Record 25 of Set 4 | smithers
# Processing Record 26 of Set 4 | sao paulo de olivenca
# Processing Record 27 of Set 4 | saint-philippe
# Processing Record 28 of Set 4 | bataipora
# Processing Record 29 of Set 4 | plastun
# Processing Record 30 of Set 4 | ulsteinvik
# Processing Record 31 of Set 4 | aykhal
# Processing Record 32 of Set 4 | ponnani
# Processing Record 33 of Set 4 | angaur state
# Processing Record 34 of Set 4 | tsiombe
# Processing Record 35 of Set 4 | rongelap
# Processing Record 36 of Set 4 | cockburn town
# Processing Record 37 of Set 4 | vilyuchinsk
# Processing Record 38 of Set 4 | lisala
# Processing Record 39 of Set 4 | sinabang
# Processing Record 40 of Set 4 | boyolangu
# Processing Record 41 of Set 4 | nguigmi
# Processing Record 42 of Set 4 | ceerigaabo
# Processing Record 43 of Set 4 | tra vinh
# Processing Record 44 of Set 4 | thompson
# Processing Record 45 of Set 4 | walvis bay
# Processing Record 46 of Set 4 | krasnyy chikoy
# Processing Record 47 of Set 4 | mundri
# Processing Record 48 of Set 4 | iskateley
# Processing Record 49 of Set 4 | roccella ionica
# Processing Record 0 of Set 5 | south hedland
# Processing Record 1 of Set 5 | aasiaat
# Processing Record 2 of Set 5 | micheweni
# Processing Record 3 of Set 5 | iranshahr
# Processing Record 4 of Set 5 | amga
# Processing Record 5 of Set 5 | macusani
# Processing Record 6 of Set 5 | qujing
# Processing Record 7 of Set 5 | coquimbo
# Processing Record 8 of Set 5 | balikpapan
# Processing Record 9 of Set 5 | port douglas
# City not found. Skipping...
# Processing Record 10 of Set 5 | kijang
# Processing Record 11 of Set 5 | puerto colombia
# Processing Record 12 of Set 5 | xanxere
# Processing Record 13 of Set 5 | sao felix do xingu
# Processing Record 14 of Set 5 | tahoua
# Processing Record 15 of Set 5 | posto fiscal rolim de moura
# Processing Record 16 of Set 5 | issenye
# Processing Record 17 of Set 5 | eyl
# Processing Record 18 of Set 5 | keflavik
# Processing Record 19 of Set 5 | torres
# Processing Record 20 of Set 5 | tokmok
# Processing Record 21 of Set 5 | anchorage
# Processing Record 22 of Set 5 | cuencame de ceniceros
# Processing Record 23 of Set 5 | timmins
# Processing Record 24 of Set 5 | kyelang
# Processing Record 25 of Set 5 | barra de santo antonio
# Processing Record 26 of Set 5 | waingapu
# Processing Record 27 of Set 5 | port lincoln
# Processing Record 28 of Set 5 | sumberpucung
# Processing Record 29 of Set 5 | hithadhoo
# Processing Record 30 of Set 5 | sandnessjoen
# Processing Record 31 of Set 5 | puerto aysen
# Processing Record 32 of Set 5 | ahau
# City not found. Skipping...
# Processing Record 33 of Set 5 | fuvahmulah
# City not found. Skipping...
# Processing Record 34 of Set 5 | whitehorse
# Processing Record 35 of Set 5 | kailua-kona
# Processing Record 36 of Set 5 | khanpur
# Processing Record 37 of Set 5 | haiku-pauwela
# Processing Record 38 of Set 5 | klyuchi
# Processing Record 39 of Set 5 | ribeira grande
# Processing Record 40 of Set 5 | wotho
# Processing Record 41 of Set 5 | la passe
# Processing Record 42 of Set 5 | segre
# Processing Record 43 of Set 5 | ontario
# Processing Record 44 of Set 5 | mitsamiouli
# Processing Record 45 of Set 5 | hengchun
# Processing Record 46 of Set 5 | papao
# Processing Record 47 of Set 5 | souillac
# Processing Record 48 of Set 5 | inirida
# Processing Record 49 of Set 5 | ebaye
# Processing Record 0 of Set 6 | pukhrayan
# Processing Record 1 of Set 6 | cidreira
# Processing Record 2 of Set 6 | hatillo
# Processing Record 3 of Set 6 | ulubey
# Processing Record 4 of Set 6 | ciudad lazaro cardenas
# Processing Record 5 of Set 6 | new norfolk
# Processing Record 6 of Set 6 | guayaramerin
# Processing Record 7 of Set 6 | mancio lima
# Processing Record 8 of Set 6 | masina
# Processing Record 9 of Set 6 | petropavlovsk-kamchatsky
# Processing Record 10 of Set 6 | pisco
# Processing Record 11 of Set 6 | alice springs
# Processing Record 12 of Set 6 | vallenar
# Processing Record 13 of Set 6 | bonthe
# Processing Record 14 of Set 6 | salmon arm
# Processing Record 15 of Set 6 | greymouth
# Processing Record 16 of Set 6 | al hudaydah
# Processing Record 17 of Set 6 | avarua
# Processing Record 18 of Set 6 | kristiansund
# Processing Record 19 of Set 6 | georgetown
# Processing Record 20 of Set 6 | barreirinhas
# Processing Record 21 of Set 6 | mokhsogollokh
# Processing Record 22 of Set 6 | port macquarie
# Processing Record 23 of Set 6 | santa terezinha
# Processing Record 24 of Set 6 | hamilton
# Processing Record 25 of Set 6 | darzab
# Processing Record 26 of Set 6 | as sulayyil
# Processing Record 27 of Set 6 | argo
# Processing Record 28 of Set 6 | tari
# Processing Record 29 of Set 6 | astrakhan
# Processing Record 30 of Set 6 | cooper's town
# Processing Record 31 of Set 6 | at taj
# Processing Record 32 of Set 6 | ta`u
# Processing Record 33 of Set 6 | asau
# Processing Record 34 of Set 6 | kalkaman
# Processing Record 35 of Set 6 | havre
# Processing Record 36 of Set 6 | palikir - national government center
# Processing Record 37 of Set 6 | lepsy
# Processing Record 38 of Set 6 | takoradi
# Processing Record 39 of Set 6 | el obeid
# Processing Record 40 of Set 6 | nantucket
# Processing Record 41 of Set 6 | kandi
# Processing Record 42 of Set 6 | gisborne
# Processing Record 43 of Set 6 | toga village
# City not found. Skipping...
# Processing Record 44 of Set 6 | luganville
# Processing Record 45 of Set 6 | katsuren-haebaru
# Processing Record 46 of Set 6 | bardai
# Processing Record 47 of Set 6 | benguela
# Processing Record 48 of Set 6 | hawaiian paradise park
# Processing Record 49 of Set 6 | malanje
# Processing Record 0 of Set 7 | jwaneng
# Processing Record 1 of Set 7 | masuguru
# Processing Record 2 of Set 7 | chimbote
# Processing Record 3 of Set 7 | palu
# Processing Record 4 of Set 7 | masterton
# Processing Record 5 of Set 7 | saint-pierre
# Processing Record 6 of Set 7 | guerrero negro
# Processing Record 7 of Set 7 | kruisfontein
# Processing Record 8 of Set 7 | akureyri
# Processing Record 9 of Set 7 | shetpe
# Processing Record 10 of Set 7 | hilo
# Processing Record 11 of Set 7 | prado
# Processing Record 12 of Set 7 | tolanaro
# Processing Record 13 of Set 7 | padang
# Processing Record 14 of Set 7 | saudarkrokur
# Processing Record 15 of Set 7 | sirsa
# Processing Record 16 of Set 7 | n'diareme limamoulaye
# City not found. Skipping...
# Processing Record 17 of Set 7 | fortuna
# Processing Record 18 of Set 7 | freetown
# Processing Record 19 of Set 7 | tommot
# Processing Record 20 of Set 7 | bidur
# Processing Record 21 of Set 7 | doksy
# Processing Record 22 of Set 7 | borujen
# Processing Record 23 of Set 7 | qarauyl
# Processing Record 24 of Set 7 | skovorodino
# Processing Record 25 of Set 7 | ondangwa
# Processing Record 26 of Set 7 | barclayville
# Processing Record 27 of Set 7 | okhotsk
# Processing Record 28 of Set 7 | st. john's
# Processing Record 29 of Set 7 | deogarh
# Processing Record 30 of Set 7 | minas de marcona
# Processing Record 31 of Set 7 | northam
# Processing Record 32 of Set 7 | yuzhno-kurilsk
# Processing Record 33 of Set 7 | kavaratti
# Processing Record 34 of Set 7 | geita
# City not found. Skipping...
# Processing Record 35 of Set 7 | san antonio de pale
# Processing Record 36 of Set 7 | san jose del cabo
# Processing Record 37 of Set 7 | abraham's bay
# City not found. Skipping...
# Processing Record 38 of Set 7 | dhidhdhoo
# Processing Record 39 of Set 7 | nijar
# Processing Record 40 of Set 7 | peterhead
# Processing Record 41 of Set 7 | nova vicosa
# Processing Record 42 of Set 7 | lively
# Processing Record 43 of Set 7 | potchefstroom
# Processing Record 44 of Set 7 | malango
# Processing Record 45 of Set 7 | taksimo
# Processing Record 46 of Set 7 | nemuro
# Processing Record 47 of Set 7 | messaad
# Processing Record 48 of Set 7 | mar del plata
# Processing Record 49 of Set 7 | kenai
# Processing Record 0 of Set 8 | kargasok
# Processing Record 1 of Set 8 | susuman
# Processing Record 2 of Set 8 | lompoc
# Processing Record 3 of Set 8 | fannuj
# City not found. Skipping...
# Processing Record 4 of Set 8 | ancud
# Processing Record 5 of Set 8 | tazovsky
# Processing Record 6 of Set 8 | ugoofaaru
# Processing Record 7 of Set 8 | syanno
# Processing Record 8 of Set 8 | moab
# Processing Record 9 of Set 8 | saldanha
# Processing Record 10 of Set 8 | christies beach
# Processing Record 11 of Set 8 | al qusayr
# Processing Record 12 of Set 8 | kingston
# Processing Record 13 of Set 8 | bela vista
# Processing Record 14 of Set 8 | urengoy
# Processing Record 15 of Set 8 | tofol
# Processing Record 16 of Set 8 | pantai cenang
# City not found. Skipping...
# Processing Record 17 of Set 8 | kiruna
# Processing Record 18 of Set 8 | campo formoso
# Processing Record 19 of Set 8 | gamba
# Processing Record 20 of Set 8 | kone
# Processing Record 21 of Set 8 | herzliya pituah
# City not found. Skipping...
# Processing Record 22 of Set 8 | taulaga
# Processing Record 23 of Set 8 | roma
# Processing Record 24 of Set 8 | isla del bosque
# Processing Record 25 of Set 8 | korets
# Processing Record 26 of Set 8 | jayapura
# Processing Record 27 of Set 8 | preobrazheniye
# Processing Record 28 of Set 8 | kinablangan
# Processing Record 29 of Set 8 | mosjoen
# Processing Record 30 of Set 8 | mawu
# Processing Record 31 of Set 8 | inhambane
# Processing Record 32 of Set 8 | la ronge
# Processing Record 33 of Set 8 | lata
# Processing Record 34 of Set 8 | shahrud
# Processing Record 35 of Set 8 | laguna
# Processing Record 36 of Set 8 | codrington
# Processing Record 37 of Set 8 | murray bridge
# Processing Record 38 of Set 8 | murzuq
# Processing Record 39 of Set 8 | kalianget
# Processing Record 40 of Set 8 | taltal
# Processing Record 41 of Set 8 | saint-joseph
# Processing Record 42 of Set 8 | taman rajawali
# City not found. Skipping...
# Processing Record 43 of Set 8 | itoman
# Processing Record 44 of Set 8 | bechar
# Processing Record 45 of Set 8 | azemmour
# Processing Record 46 of Set 8 | montalbano jonico
# Processing Record 47 of Set 8 | punta del este
# Processing Record 48 of Set 8 | miacatlan
# Processing Record 49 of Set 8 | meizhou
# Processing Record 0 of Set 9 | joao pinheiro
# Processing Record 1 of Set 9 | guajara mirim
# Processing Record 2 of Set 9 | ashkelon
# Processing Record 3 of Set 9 | gillette
# Processing Record 4 of Set 9 | vinh long
# Processing Record 5 of Set 9 | sisimiut
# Processing Record 6 of Set 9 | mount pleasant
# Processing Record 7 of Set 9 | beaufort west
# Processing Record 8 of Set 9 | luderitz
# Processing Record 9 of Set 9 | endicott
# Processing Record 10 of Set 9 | gaspe
# Processing Record 11 of Set 9 | douvres-la-delivrande
# Processing Record 12 of Set 9 | akhtubinsk
# Processing Record 13 of Set 9 | masasi
# Processing Record 14 of Set 9 | shimanovsk
# Processing Record 15 of Set 9 | izluchinsk
# Processing Record 16 of Set 9 | hosdurga
# Processing Record 17 of Set 9 | bereeda
# Processing Record 18 of Set 9 | quesnel
# Processing Record 19 of Set 9 | barah
# Processing Record 20 of Set 9 | agat village
# Processing Record 21 of Set 9 | boca chica
# Processing Record 22 of Set 9 | cannonvale
# Processing Record 23 of Set 9 | umm kaddadah
# Processing Record 24 of Set 9 | egilsstadir
# Processing Record 25 of Set 9 | kolonia
# Processing Record 26 of Set 9 | qal'at bishah
# City not found. Skipping...
# Processing Record 27 of Set 9 | bikenibeu village
# Processing Record 28 of Set 9 | la romana
# Processing Record 29 of Set 9 | mejit
# Processing Record 30 of Set 9 | edmundston
# Processing Record 31 of Set 9 | belyy yar
# Processing Record 32 of Set 9 | flin flon
# Processing Record 33 of Set 9 | cuenca
# Processing Record 34 of Set 9 | bondo
# Processing Record 35 of Set 9 | kill devil hills
# Processing Record 36 of Set 9 | rawlins
# Processing Record 37 of Set 9 | cruzeiro do sul
# Processing Record 38 of Set 9 | myskhako
# Processing Record 39 of Set 9 | maile
# Processing Record 40 of Set 9 | starkville
# Processing Record 41 of Set 9 | tuxpan
# Processing Record 42 of Set 9 | dainava (kaunas)
# Processing Record 43 of Set 9 | safford
# Processing Record 44 of Set 9 | port-vila
# Processing Record 45 of Set 9 | shingu
# Processing Record 46 of Set 9 | alofi
# Processing Record 47 of Set 9 | sittwe
# Processing Record 48 of Set 9 | praia da vitoria
# Processing Record 49 of Set 9 | luena
# Processing Record 0 of Set 10 | north battleford
# Processing Record 1 of Set 10 | pariaman
# Processing Record 2 of Set 10 | kalmunai
# Processing Record 3 of Set 10 | manuel ojinaga
# City not found. Skipping...
# Processing Record 4 of Set 10 | linghai
# Processing Record 5 of Set 10 | belmonte
# Processing Record 6 of Set 10 | howard springs
# Processing Record 7 of Set 10 | sol'-iletsk
# Processing Record 8 of Set 10 | sabana de torres
# Processing Record 9 of Set 10 | trujillo
# Processing Record 10 of Set 10 | amahai
# Processing Record 11 of Set 10 | margate
# Processing Record 12 of Set 10 | cidade velha
# Processing Record 13 of Set 10 | n'zeto
# Processing Record 14 of Set 10 | namsos
# Processing Record 15 of Set 10 | crane
# Processing Record 16 of Set 10 | palmer
# Processing Record 17 of Set 10 | szczebrzeszyn
# Processing Record 18 of Set 10 | maumere
# Processing Record 19 of Set 10 | tralee
# Processing Record 20 of Set 10 | ed damer
# Processing Record 21 of Set 10 | tazacorte
# Processing Record 22 of Set 10 | north bend
# Processing Record 23 of Set 10 | batticaloa
# Processing Record 24 of Set 10 | dubreka
# Processing Record 25 of Set 10 | loreto
# Processing Record 26 of Set 10 | lower sackville
# Processing Record 27 of Set 10 | axim
# Processing Record 28 of Set 10 | markovo
# Processing Record 29 of Set 10 | sirte
# Processing Record 30 of Set 10 | canutama
# Processing Record 31 of Set 10 | hotan
# Processing Record 32 of Set 10 | fort irwin
# Processing Record 33 of Set 10 | hibbing
# Processing Record 34 of Set 10 | morondava
# Processing Record 35 of Set 10 | laojunmiao
# Processing Record 36 of Set 10 | cole harbour
# Processing Record 37 of Set 10 | mossendjo
# Processing Record 38 of Set 10 | clinton
# Processing Record 39 of Set 10 | farafangana
# Processing Record 40 of Set 10 | ofunato
# Processing Record 41 of Set 10 | zhezqazghan
# Processing Record 42 of Set 10 | ivins
# Processing Record 43 of Set 10 | alibag
# Processing Record 44 of Set 10 | zeya
# Processing Record 45 of Set 10 | auki
# Processing Record 46 of Set 10 | ouellah
# City not found. Skipping...
# Processing Record 47 of Set 10 | namtsy
# Processing Record 48 of Set 10 | kavieng
# Processing Record 49 of Set 10 | kalavoor
# City not found. Skipping...
# Processing Record 0 of Set 11 | al bayda'
# Processing Record 1 of Set 11 | cill airne
# Processing Record 2 of Set 11 | tateyama
# Processing Record 3 of Set 11 | le puy-en-velay
# Processing Record 4 of Set 11 | san andres
# Processing Record 5 of Set 11 | sangsong-ni
# Processing Record 6 of Set 11 | manokwari
# Processing Record 7 of Set 11 | kerikeri
# Processing Record 8 of Set 11 | noumea
# Processing Record 9 of Set 11 | changli
# Processing Record 10 of Set 11 | pandan
# Processing Record 11 of Set 11 | borovskoy
# Processing Record 12 of Set 11 | revda
# Processing Record 13 of Set 11 | aioun
# Processing Record 14 of Set 11 | beyneu
# Processing Record 15 of Set 11 | ouallam
# Processing Record 16 of Set 11 | bouznika
# Processing Record 17 of Set 11 | carrigaline
# Processing Record 18 of Set 11 | reggane
# Processing Record 19 of Set 11 | dolores
# Processing Record 20 of Set 11 | rio grande
# Processing Record 21 of Set 11 | luanda
# Processing Record 22 of Set 11 | bayan nur
# City not found. Skipping...
# Processing Record 23 of Set 11 | santona
# Processing Record 24 of Set 11 | tobelo
# Processing Record 25 of Set 11 | hadibu
# Processing Record 26 of Set 11 | maloye ganyushkino
# Processing Record 27 of Set 11 | westport
# Processing Record 28 of Set 11 | pechora
# Processing Record 29 of Set 11 | brookings
# Processing Record 30 of Set 11 | harran
# Processing Record 31 of Set 11 | sona
# Processing Record 32 of Set 11 | yura
# Processing Record 33 of Set 11 | civitavecchia
# Processing Record 34 of Set 11 | amalapuram
# Processing Record 35 of Set 11 | winnemucca
# Processing Record 36 of Set 11 | tvoroyri
# Processing Record 37 of Set 11 | buedu
# Processing Record 38 of Set 11 | howrah
# Processing Record 39 of Set 11 | lorengau
# Processing Record 40 of Set 11 | port blair
# Processing Record 41 of Set 11 | mogadishu
# Processing Record 42 of Set 11 | hiratacho
# Processing Record 43 of Set 11 | melfort
# Processing Record 44 of Set 11 | tobi village
# City not found. Skipping...
# Processing Record 45 of Set 11 | salym
# Processing Record 46 of Set 11 | zemio
# Processing Record 47 of Set 11 | kolonia town
# Processing Record 48 of Set 11 | rikaze
# Processing Record 49 of Set 11 | lander
# Processing Record 0 of Set 12 | salinopolis
# Processing Record 1 of Set 12 | yaren
# Processing Record 2 of Set 12 | arenapolis
# Processing Record 3 of Set 12 | kavalerovo
# Processing Record 4 of Set 12 | ashoknagar
# Processing Record 5 of Set 12 | sur
# Processing Record 6 of Set 12 | tumut
# Processing Record 7 of Set 12 | alaghsas
# Processing Record 8 of Set 12 | richards bay
# Processing Record 9 of Set 12 | huarmey
# Processing Record 10 of Set 12 | puerto leguizamo
# Processing Record 11 of Set 12 | ubari
# Processing Record 12 of Set 12 | vestby
# Processing Record 13 of Set 12 | nuuk
# Processing Record 14 of Set 12 | siwa oasis
# Processing Record 15 of Set 12 | labuan bajo
# Processing Record 16 of Set 12 | thames
# Processing Record 17 of Set 12 | bulgan
# Processing Record 18 of Set 12 | jijiang
# Processing Record 19 of Set 12 | omoku
# Processing Record 20 of Set 12 | ayorou
# Processing Record 21 of Set 12 | kurumkan
# Processing Record 22 of Set 12 | prata
# Processing Record 23 of Set 12 | beledweyne
# Processing Record 24 of Set 12 | aswan
# Processing Record 25 of Set 12 | hobyo
# Processing Record 26 of Set 12 | jining
# Processing Record 27 of Set 12 | tabou
# Processing Record 28 of Set 12 | estes park
# Processing Record 29 of Set 12 | aykol
# City not found. Skipping...
# Processing Record 30 of Set 12 | kobuleti
# Processing Record 31 of Set 12 | sarmiento
# Processing Record 32 of Set 12 | mugia
# Processing Record 33 of Set 12 | quchan
# Processing Record 34 of Set 12 | dolinsk
# Processing Record 35 of Set 12 | ambodivoara
# City not found. Skipping...
# Processing Record 36 of Set 12 | balkanabat
# Processing Record 37 of Set 12 | istok
# Processing Record 38 of Set 12 | fallon
# Processing Record 39 of Set 12 | dalbandin
# Processing Record 40 of Set 12 | bageshwar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          563
# Lat           563
# Lng           563
# Max Temp      563
# Humidity      563
# Cloudiness    563
# Wind Speed    563
# Country       563
# Date          563
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         colonia  50.9333    6.9500     15.53        73           0
# 1           opuwo -18.0607   13.8400     14.29        24           9
# 2  port elizabeth -33.9180   25.5701     15.17        89         100
# 3       grytviken -54.2811  -36.5092     -4.41        76           8
# 4            naze  28.3667  129.4833     23.51        92          94
#
#    Wind Speed Country        Date
# 0        4.63      DE  1685484181
# 1        1.84      NA  1685484408
# 2        1.79      ZA  1685484191
# 3        2.21      GS  1685484152
# 4        2.60      JP  1685484377

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               colonia  50.9333    6.9500     15.53        73           0
# 1                 opuwo -18.0607   13.8400     14.29        24           9
# 2        port elizabeth -33.9180   25.5701     15.17        89         100
# 3             grytviken -54.2811  -36.5092     -4.41        76           8
# 4                  naze  28.3667  129.4833     23.51        92          94
#
#          Wind Speed Country        Date
# City_ID
# 0              4.63      DE  1685484181
# 1              1.84     NaN  1685484408
# 2              1.79      ZA  1685484191
# 3              2.21      GS  1685484152
# 4              2.60      JP  1685484377

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(
    city_data_df["Lat"], 
    city_data_df["Max Temp"], 
    marker="o", 
    linewidths = 1,
    edgecolors="black",
    alpha= .8,
    label = "Cities")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature (2023-01-11)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(
    city_data_df["Lat"], 
    city_data_df["Humidity"], 
    marker="o", 
    edgecolors="black", 
    label = "Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (2023-01-11)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(
    city_data_df["Lat"], 
    city_data_df["Cloudiness"], 
    marker = "o",
    linewidths=1,
    edgecolor="black")
# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (2023-01-11)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# YOUR CODE HERE

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(
    city_data_df["Lat"], 
    city_data_df["Wind Speed"], 
    marker="o",
    alpha = .8,
    linewidths =1,
    edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (2023-01-11)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    # Compute linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
  
    # Plot
    plt.scatter(x_values,y_values, color="blue")
    plt.plot(x_values,regress_values,color="red")
    plt.xlabel("Latitude")
    plt.ylabel(title)
    plt.annotate(line_eq, text_coordinates , fontsize = 14, color = "blue")
    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0

northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              colonia  50.9333    6.9500     15.53        73           0
# 4                 naze  28.3667  129.4833     23.51        92          94
# 6              talnakh  69.4865   88.3972      5.67        72          94
# 7        fort st. john  56.2499 -120.8529     15.94        41          40
# 8                utrik  11.2278  169.8474     27.50        80         100
#
#          Wind Speed Country        Date
# City_ID
# 0              4.63      DE  1685484181
# 4              2.60      JP  1685484377
# 6              5.22      RU  1685484181
# 7              3.60      CA  1685484110
# 8              7.87      MH  1685484207

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1                    opuwo -18.0607  13.8400     14.29        24           9
# 2           port elizabeth -33.9180  25.5701     15.17        89         100
# 3                grytviken -54.2811 -36.5092     -4.41        76           8
# 5             puerto ayora  -0.7393 -90.3518     29.98        92          90
# 14       port-aux-francais -49.3500  70.2167      4.75        87          98
#
#          Wind Speed Country        Date
# City_ID
# 1              1.84     NaN  1685484408
# 2              1.79      ZA  1685484191
# 3              2.21      GS  1685484152
# 5              1.79      EC  1685484159
# 14            15.16      TF  1685484166

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
 # Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp",(-10, 50))
# Out:
# The r-value is: 0.5873793246401813

# %%
 # Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (-80, 50))
# Out:
# The r-value is: 0.6067662273664962

# %% [markdown]
# **Discussion about the linear relationship:** The higher the r value, the more positive of the relationship between the Max Temp vs. Latitude. Since the above models have  around .6 for both north and southern hemisphere, the relationship between Max Temp and latitude are just moderately positive relationship.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity",(-10, 50))
# Out:
# The r-value is: 0.007282427520109872

# %%
 # Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (-50, 20))
# Out:
# The r-value is: 8.895886251185173e-05

# %% [markdown]
# **Discussion about the linear relationship:** since r is very small to the point of 0, there is no relationship between humidity vs. latitude in the northern and southern hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
 # Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (40,20))
# Out:
# The r-value is: 0.003203980450098167

# %%
 # Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (-30,30))
# Out:
# The r-value is: 0.0019525710751982642

# %% [markdown]
# **Discussion about the linear relationship:** r value for both the the graphs above are very small, technically 0. Therefore, we can conclude that there are no relationship between Cloudiness vs. latitude in both northern and southern hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
 # Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (10,12))
# Out:
# The r-value is: 0.00880590558617164

# %%
 # Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (-50, 12))
# Out:
# The r-value is: 0.044335497931579745

# %% [markdown]
# **Discussion about the linear relationship:** The low r values for both of the graph above indicates that there is no relationship for both latitude vs. windspeed for both Northern and Southern hemispheres.
